# %%
import sqlite3
import logging
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from transformers import pipeline
from typing import List, Dict, Tuple

# Configure logging to print to the notebook output
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# Download the VADER lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Initialize the sentiment analysis pipelines
pipelines = {
    "FinBERT": pipeline("text-classification", model="ProsusAI/finbert"),
    "DistilBERT": pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english", revision="af0f99b"),
    "FinBERT Tone": pipeline("text-classification", model="yiyanghkust/finbert-tone"),
    "DistilRoberta": pipeline("text-classification", model="mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"),
    "FinTwitBERT": pipeline("text-classification", model="StephanAkkerman/FinTwitBERT-sentiment"),
    "Sentiment Roberta": pipeline("text-classification", model="siebert/sentiment-roberta-large-english")
}

# Function to connect to the database and fetch news data
def fetch_news_from_db(db_path: str, query: str) -> List[Dict]:
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute(query)
        rows = cursor.fetchall()
        conn.close()
        # Convert rows to a list of dictionaries
        news_data = []
        for row in rows:
            news_data.append({"title": row[0], "text": row[1]})
        return news_data
    except sqlite3.Error as e:
        logger.error(f"Error fetching news data from database: {e}")
        return []

# Function to preprocess text data
def preprocess_text(text: str) -> str:
    text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = text.strip()  # Remove leading and trailing whitespace
    return text

# Function to analyze sentiment using multiple models
def analyze_sentiment(text: str) -> List[Tuple[str, Dict]]:
    results = []
    text = preprocess_text(text)

    # VADER
    vader_result = sia.polarity_scores(text)
    if vader_result['compound'] != 0:
        label = 'POSITIVE' if vader_result['compound'] > 0 else 'NEGATIVE'
        results.append(('VADER', {'label': label, 'score': abs(vader_result['compound'])}))

    # Other models
    for model_name, sentiment_pipeline in pipelines.items():
        result = sentiment_pipeline(text)
        if result:
            label = result[0]['label']
            score = result[0]['score']
            # Normalize label and score interpretation
            if label.lower() in ['positive', 'negative', 'neutral', 'bullish', 'bearish']:
                normalized_label = label.upper()
                if normalized_label in ['POSITIVE', 'BULLISH']:
                    normalized_score = score
                elif normalized_label in ['NEGATIVE', 'BEARISH']:
                    normalized_score = -score
                else:
                    normalized_score = 0  # Neutral scores should contribute 0
                results.append((model_name, {'label': normalized_label, 'score': normalized_score}))

    return results

# Function to calculate the ensemble sentiment score
def ensemble_sentiment(sentiments: List[Tuple[str, Dict]]) -> Tuple[float, str]:
    weights = {
        'FinBERT': 3,
        'FinBERT Tone': 3,
        'Sentiment Roberta': 3,
        'DistilRoberta': 2,
        'FinTwitBERT': 1,
        'DistilBERT': 1,
        'VADER': 1
    }
    score = 0
    total_weight = 0
    for model, sentiment in sentiments:
        weight = weights.get(model, 1)
        total_weight += weight
        score += weight * sentiment['score']
    if total_weight == 0:
        return 0.0, "NEUTRAL"
    final_score = score / total_weight
    final_label = 'POSITIVE' if final_score > 0 else 'NEGATIVE'
    return final_score, final_label

# Function to process and display news articles
def process_news_articles(news_data: List[Dict]) -> None:
    if not news_data:
        logger.info("No news data to process.")
        return

    for article in news_data:
        headline = article.get("title", "")
        snippet = article.get("text", "")

        # Combine headline and snippet
        combined_text = f"{headline} {snippet}"

        # Analyze sentiment of the combined text
        combined_sentiments = analyze_sentiment(combined_text)

        # Calculate ensemble sentiment
        combined_ensemble_score, combined_ensemble_label = ensemble_sentiment(combined_sentiments)

        # Print the results
        print(f"\n{'-'*80}")
        print(f"Headline: {headline}")
        print(f"Snippet: {snippet}")
        print(f"Combined Ensemble Sentiment Score: {combined_ensemble_score:.2f} ({combined_ensemble_label})")
        print("Combined Sentiments:")
        for model, sentiment in combined_sentiments:
            print(f"  - {model}: {sentiment['label']} (score: {sentiment['score']:.2f})")
        print(f"{'-'*80}\n")

# Main function
def main():
    db_path = "News.db"
    query = "SELECT * FROM stock_news"

    news_data = fetch_news_from_db(db_path, query)
    if news_data:
        process_news_articles(news_data)
    else:
        logger.error("Failed to fetch news data.")

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# --------------------------------------------------------------------------------
# Headline: AMD
# Snippet: AMD Inventory Headwinds & Robust MRVL Demand
# Combined Ensemble Sentiment Score: 0.42 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.23)
#   - FinBERT: NEGATIVE (score: -0.73)
#   - DistilBERT: POSITIVE (score: 0.98)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.90)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: GOOGL
# Snippet: Google's Kurian approached Wiz, $23B deal could take a week to close, source says
# Combined Ensemble Sentiment Score: -0.26 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.56)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: GOOG
# Snippet: Alphabet (GOOGL) Exceeds Market Returns: Some Facts to Consider
# Combined Ensemble Sentiment Score: 0.39 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.97)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: AMZN
# Snippet: Could This Be Amazon's Next $100 Billion Business?
# Combined Ensemble Sentiment Score: 0.15 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: AAL
# Snippet: American Airlines releases 2023 Sustainability Report
# Combined Ensemble Sentiment Score: 0.30 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.97)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: AAPL
# Snippet: Apple gains after Morgan Stanley calls stock 'top pick' for AI efforts
# Combined Ensemble Sentiment Score: 0.80 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.49)
#   - FinBERT: POSITIVE (score: 0.78)
#   - DistilBERT: NEGATIVE (score: -0.52)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.94)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: T
# Snippet: Can Retirees Still Trust AT&T's 5.8% Dividend Yield?
# Combined Ensemble Sentiment Score: 0.14 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.51)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.52)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: BAC
# Snippet: Bank of America: Let Your Winners Run
# Combined Ensemble Sentiment Score: -0.12 (NEGATIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.48)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.51)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.68)
#   - Sentiment Roberta: NEGATIVE (score: -0.79)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: BIIB
# Snippet: IMMINENT BIIB DEADLINE: Bronstein, Gewirtz & Grossman LLC Reminds Biogen Inc. Investors to Join the Class Action Lawsuit
# Combined Ensemble Sentiment Score: 0.08 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.08)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.87)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: BLK
# Snippet: BlackRock announces $3.22 billion acquisition of Preqin
# Combined Ensemble Sentiment Score: 0.29 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.81)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: BA
# Snippet: Boeing Delivers Most Planes Since Alaska Airlines Blowout—But Still Trails Competitor Airbus
# Combined Ensemble Sentiment Score: 0.69 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: POSITIVE (score: 0.80)
#   - DistilBERT: POSITIVE (score: 0.98)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: POSITIVE (score: 0.99)
#   - FinTwitBERT: BULLISH (score: 0.65)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: AVGO
# Snippet: Broadcom Stock Gets Price-Target Hike For AI Strength
# Combined Ensemble Sentiment Score: 0.75 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.49)
#   - FinBERT: POSITIVE (score: 0.69)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.88)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CVX
# Snippet: Chevron (CVX) Stock Barely Moves in a Month: An Opportunity?
# Combined Ensemble Sentiment Score: -0.39 (NEGATIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.42)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEGATIVE (score: -0.96)
#   - DistilRoberta: POSITIVE (score: 0.99)
#   - FinTwitBERT: BEARISH (score: -0.99)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CMG
# Snippet: "TEAM CHIPOTLE" RETURNS WITH A NEW LIMITED-TIME MENU FEATURING THE GO-TO ORDERS FOR AMERICA'S TOP ATHLETES
# Combined Ensemble Sentiment Score: 0.22 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.20)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.63)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.53)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: C
# Snippet: JPMorgan downgraded on valuation, while Bank of America shines as top pick: analyst
# Combined Ensemble Sentiment Score: 0.04 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.20)
#   - FinBERT: NEGATIVE (score: -0.44)
#   - DistilBERT: POSITIVE (score: 0.99)
#   - FinBERT Tone: NEGATIVE (score: -1.00)
#   - DistilRoberta: POSITIVE (score: 0.84)
#   - FinTwitBERT: BEARISH (score: -0.99)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: COST
# Snippet: Gen Z Discovers Costco, Sam's Club and the Joy of Buying Groceries in Bulk
# Combined Ensemble Sentiment Score: 0.33 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.59)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CRWD
# Snippet: CrowdStrike faces major brand damage from global outage but analysts remain bullish on long-term potential
# Combined Ensemble Sentiment Score: -0.31 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.27)
#   - FinBERT: NEGATIVE (score: -0.92)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: NEGATIVE (score: -0.64)
#   - FinTwitBERT: BULLISH (score: 0.39)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CVS
# Snippet: CVS Health Corporation Is Under Probe By The Schall Law Firm Regarding Certain Allegations And Investors Are Urged To Participate In The Investigation
# Combined Ensemble Sentiment Score: 0.09 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.27)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.96)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.99)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: DAL
# Snippet: Should You Buy Delta Air Lines Stock Ahead of Q2 Earnings?
# Combined Ensemble Sentiment Score: 0.15 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: ENPH
# Snippet: Enphase Energy, Inc. Sued for Securities Law Violations - Contact The Gross Law Firm Before July 29, 2024 to Discuss Your Rights – ENPH
# Combined Ensemble Sentiment Score: -0.51 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.49)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEGATIVE (score: -0.95)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.87)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: GM
# Snippet: Chief Future Officer: Kofi Bruce, General Mills
# Combined Ensemble Sentiment Score: 0.31 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: GS
# Snippet: 2 factors that could boost big bank stocks
# Combined Ensemble Sentiment Score: 0.82 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.40)
#   - FinBERT: POSITIVE (score: 0.72)
#   - DistilBERT: POSITIVE (score: 0.98)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: HUM
# Snippet: HUM SHAREHOLDER ALERT: Bronstein, Gewirtz & Grossman LLC Reminds Humana Inc. Investors to Join the Class Action Lawsuit!
# Combined Ensemble Sentiment Score: 0.12 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.55)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.85)
#   - Sentiment Roberta: POSITIVE (score: 0.97)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: INTC
# Snippet: Forget Nvidia: These 2 AI Stocks Are Better Bargain Buys Right Now.
# Combined Ensemble Sentiment Score: 0.58 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.42)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 0.99)
#   - FinTwitBERT: BULLISH (score: 0.71)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: JNJ
# Snippet: CARVYKTI® (ciltacabtagene autoleucel) achieved statistically significant and clinically meaningful improvement in overall survival in landmark CARTITUDE-4 study
# Combined Ensemble Sentiment Score: 0.96 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.75)
#   - FinBERT: POSITIVE (score: 0.95)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.84)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: JPM
# Snippet: 3 Must-Watch Financial Stocks as Sector Approaches Major Breakout
# Combined Ensemble Sentiment Score: 0.38 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.95)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: LW
# Snippet: Investors in Lamb Weston Holdings, Inc. Should Contact Levi & Korsinsky Before August 12, 2024 to Discuss Your Rights - LW
# Combined Ensemble Sentiment Score: -0.27 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.52)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: LLY
# Snippet: Here's Why Eli Lilly (LLY) is a Strong Momentum Stock
# Combined Ensemble Sentiment Score: 0.75 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.51)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.99)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.95)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: META
# Snippet: 9 Popular AI Stocks to Buy With $500 Right Now
# Combined Ensemble Sentiment Score: 0.34 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.42)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.70)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.65)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: MU
# Snippet: Micron: Market Overreacted, Time To Load Up - Maintaining Buy
# Combined Ensemble Sentiment Score: 0.20 (POSITIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.40)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: POSITIVE (score: 0.99)
#   - DistilRoberta: NEGATIVE (score: -0.98)
#   - FinTwitBERT: BEARISH (score: -0.56)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: MSFT
# Snippet: 3 Growth Beasts (Not Named Nvidia) That Have Been 10-Baggers Over the Past 10 Years
# Combined Ensemble Sentiment Score: -0.19 (NEGATIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.38)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.96)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: MS
# Snippet: This is how much the largest 20 U.S. banks raised dividends after stress tests
# Combined Ensemble Sentiment Score: 0.26 (POSITIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.42)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BEARISH (score: -0.81)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: NDAQ
# Snippet: Nasdaq Gains 1%; LegalZoom Shares Slide
# Combined Ensemble Sentiment Score: 0.53 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.56)
#   - FinBERT: POSITIVE (score: 0.91)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.87)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: NFLX
# Snippet: Netflix Q2 Earnings Highlights: Revenue Beat, EPS Beat, Advertising Revenue 'More Meaningful,' 'Squid Game' Multiplayer Game Coming
# Combined Ensemble Sentiment Score: 0.72 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.72)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.70)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: NKE
# Snippet: Class Action Filed Against NIKE, Inc. (NKE) Seeking Recovery for Investors - Contact Levi & Korsinsky
# Combined Ensemble Sentiment Score: -0.56 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEGATIVE (score: -0.76)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.99)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: NVDA
# Snippet: Nvidia, ASML and Other Chip Stocks Sink on Worries About Tougher Trade Curbs, Geopolitics
# Combined Ensemble Sentiment Score: -0.89 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.27)
#   - FinBERT: NEGATIVE (score: -0.92)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEGATIVE (score: -1.00)
#   - DistilRoberta: NEGATIVE (score: -1.00)
#   - FinTwitBERT: BEARISH (score: -1.00)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: PARA
# Snippet: Special committee of Paramount Global endorses plan to merge with Skydance Media, source says
# Combined Ensemble Sentiment Score: 0.19 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.62)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.94)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: PEP
# Snippet: 7 Diversified Income Powerhouses for Lifelong Cash Flow
# Combined Ensemble Sentiment Score: 0.36 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.72)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: PFE
# Snippet: Weighing the Future of Weight Loss Drugs
# Combined Ensemble Sentiment Score: 0.12 (POSITIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.32)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.60)
#   - Sentiment Roberta: POSITIVE (score: 0.98)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: O
# Snippet: Dividend Harvesting Portfolio Week 174: $17,400 Allocated, $1,552.82 In Projected Dividends
# Combined Ensemble Sentiment Score: 0.15 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CRM
# Snippet: CRM INVESTIGATION NOTIFICATION: BFA Law Notifies Salesforce, Inc. (NYSE:CRM) Investors that it is Investigating Salesforce for Securities Fraud, Contact Us if You Lost Money
# Combined Ensemble Sentiment Score: -0.45 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.60)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEGATIVE (score: -0.62)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -1.00)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: SMCI
# Snippet: 1 Phenomenal Stock That Could Join Microsoft, Apple, Nvidia, Alphabet, Amazon, and Meta in the $1 Trillion Club
# Combined Ensemble Sentiment Score: 0.52 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.44)
#   - FinBERT: POSITIVE (score: 0.61)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.96)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: TGT
# Snippet: Target Hospitality Being Investigated on Behalf of Target Hospitality Corp. Investors. Contact Levi & Korsinsky For Details
# Combined Ensemble Sentiment Score: -0.25 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.62)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.87)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: TSLA
# Snippet: 3 Stocks Down 42% to 75% to Buy Right Now
# Combined Ensemble Sentiment Score: -0.97 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEGATIVE (score: -0.96)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEGATIVE (score: -0.99)
#   - DistilRoberta: NEGATIVE (score: -1.00)
#   - FinTwitBERT: BEARISH (score: -0.78)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: UNH
# Snippet: UNITEDHEALTH SHAREHOLDER ALERT BY FORMER LOUISIANA ATTORNEY GENERAL: KAHN SWICK & FOTI, LLC REMINDS INVESTORS WITH LOSSES IN EXCESS OF $100,000 of Lead Plaintiff Deadline in Class Action Lawsuit Against UnitedHealth Group Inc.- UNH
# Combined Ensemble Sentiment Score: -0.53 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.34)
#   - FinBERT: NEGATIVE (score: -0.92)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -1.00)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: V
# Snippet: Visa Promotes Aurélien Pichon to Global Head of Client Services
# Combined Ensemble Sentiment Score: 0.31 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.34)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: WBA
# Snippet: 3 Things You Need to Know if You Buy Walgreens Boots Alliance Stock Today
# Combined Ensemble Sentiment Score: 0.15 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: WMT
# Snippet: Walmart Chile workers' union launches strike after talks fail
# Combined Ensemble Sentiment Score: -0.63 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.61)
#   - FinBERT: NEGATIVE (score: -0.94)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEGATIVE (score: -0.92)
#   - FinTwitBERT: BEARISH (score: -0.80)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------

# %%
import sqlite3

# Connect to the database [stock_news, fmp_articles]
conn = sqlite3.connect('News.db')

# Create a cursor object
cursor = conn.cursor()

# Execute a query
cursor.execute("SELECT * FROM stock_news")

# Fetch the results
rows = cursor.fetchall()
for row in rows:
    print(row)

# Close the connection
conn.close()
# Out:
# ('AMD', 'AMD Inventory Headwinds & Robust MRVL Demand', '2024-07-09 12:05:35', 'youtube.com', "AMD's (AMD) takeaways from Asia are mixed, according to a Keybanc analyst. The analyst also highlights that Marvell's (MRVL) feedback indicates demand for optical networking is robust across all segments.", 'https://www.youtube.com/watch?v=3CG2Y41ueUg')
# ('GOOGL', "Google's Kurian approached Wiz, $23B deal could take a week to close, source says", '2024-07-15 14:34:47', 'techcrunch.com', "Alphabet, Google's parent company, is in advanced talks to acquire Wiz for $23 billion, a person close to the company told TechCrunch. The deal discussions were previously reported by the Wall Street Journal.", 'https://techcrunch.com/2024/07/15/googles-kurian-approached-wiz-23b-deal-could-take-a-week-to-close-source-says/')
# ('GOOG', 'Alphabet (GOOGL) Exceeds Market Returns: Some Facts to Consider', '2024-07-15 18:51:05', 'zacks.com', 'The latest trading day saw Alphabet (GOOGL) settling at $186.53, representing a +0.79% change from its previous close.', 'https://www.zacks.com/stock/news/2302069/alphabet-googl-exceeds-market-returns-some-facts-to-consider?cid=CS-STOCKNEWSAPI-FT-tale_of_the_tape|yseop_template_6-2302069')
# ('AMZN', "Could This Be Amazon's Next $100 Billion Business?", '2024-07-17 05:50:00', 'fool.com', "Amazon's robotaxi business, Zoox, recently achieved several major milestones. Ark Invest predicts the robotaxi market could grow to as much as $10 trillion by 2030.", 'https://www.fool.com/investing/2024/07/17/could-this-be-amazons-next-100-billion-business/')
# ('AAL', 'American Airlines releases 2023 Sustainability Report', '2024-07-02 15:00:00', 'globenewswire.com', "FORT WORTH, Texas, July 02, 2024 (GLOBE NEWSWIRE) -- American Airlines released its 2023 Sustainability Report today, documenting its work to advance the company's strategy to address climate change and accelerate the broader solutions needed to decarbonize aviation, and sharing progress on other issues important to the company and its stakeholders — including safety, human capital and customer experience.", 'https://www.globenewswire.com/news-release/2024/07/02/2907750/0/en/American-Airlines-releases-2023-Sustainability-Report.html')
# ('AAPL', "Apple gains after Morgan Stanley calls stock 'top pick' for AI efforts", '2024-07-15 07:36:58', 'reuters.com', 'Apple\'s shares rose about 2% on Monday after Morgan Stanley raised its price target on the iPhone maker\'s shares and designated the stock as a "top pick," citing the company\'s AI efforts as a boost to device sales.', 'https://www.reuters.com/technology/apple-gains-after-morgan-stanley-calls-stock-top-pick-ai-efforts-2024-07-15/')
# ('T', "Can Retirees Still Trust AT&T's 5.8% Dividend Yield?", '2024-07-02 07:00:00', 'fool.com', "AT&T's failed media ambitions set the company back. Its financials have dramatically improved in recent years.", 'https://www.fool.com/investing/2024/07/02/can-retirees-still-trust-atts-58-dividend-yield/')
# ('BAC', 'Bank of America: Let Your Winners Run', '2024-07-09 11:30:25', 'seekingalpha.com', "Bank of America investors have outperformed the S&P 500 recently. BofA has a solid banking franchise, benefiting from a higher-for-longer Fed. BAC's exposure to CRE loans is expected to remain well-controlled.", 'https://seekingalpha.com/article/4703153-bank-of-america-let-your-winners-run')
# ('BIIB', 'IMMINENT BIIB DEADLINE: Bronstein, Gewirtz & Grossman LLC Reminds Biogen Inc. Investors to Join the Class Action Lawsuit', '2024-07-14 05:00:00', 'accesswire.com', 'NEW YORK, NY / ACCESSWIRE / July 14, 2024 / Bronstein, Gewirtz & Grossman, LLC, a nationally recognized law firm, notifies investors that a class action lawsuit has been filed against Biogen Inc. ("Biogen Inc." or "the Company") (NASDAQ:BIIB) and certain of its officers. Class Definition: This lawsuit seeks to recover damages against Defendants for alleged violations of the federal securities laws on behalf of all persons and entities that purchased or otherwise acquired Biogen Inc. securities between February 3, 2022 and February 13, 2024, inclusive (the "Class Period").', 'https://www.accesswire.com/viewarticle.aspx?id=869104&lang=en')
# ('BLK', 'BlackRock announces $3.22 billion acquisition of Preqin', '2024-07-01 07:00:01', 'youtube.com', "CNBC's Leslie Picker joins 'Squawk Box' to report on BlackRock as the New York-based company announced its plan to acquire private capital database provider Preqin for $3.22 billion.", 'https://www.youtube.com/watch?v=2hU1Akog1mQ')
# ('BA', 'Boeing Delivers Most Planes Since Alaska Airlines Blowout—But Still Trails Competitor Airbus', '2024-07-09 13:17:39', 'forbes.com', 'Boeing delivered more commercial planes last month than at any other point this year, the company announced Tuesday, following delays in production and deliveries for the aerospace firm, which has faced increased scrutiny since a metal door plug flew off an Alaska Airlines 737 earlier this year.', 'https://www.forbes.com/sites/tylerroush/2024/07/09/boeing-delivers-most-planes-since-alaska-airlines-blowout-but-still-trails-competitor-airbus/')
# ('AVGO', 'Broadcom Stock Gets Price-Target Hike For AI Strength', '2024-07-11 10:47:16', 'investors.com', 'Broadcom stock nabbed a price-target hike Thursday from a Wall Street analyst as it gains from the artificial intelligence trend.', 'https://www.investors.com/news/technology/broadcom-stock-gets-price-target-hike-for-ai-strength/')
# ('CVX', 'Chevron (CVX) Stock Barely Moves in a Month: An Opportunity?', '2024-07-03 09:50:21', 'zacks.com', "Chevron's (CVX) robust financial performance in Q1, with $5.5 billion in earnings and a free cash flow yield of over 5%, underscores its strong profitability and operational efficiency.", 'https://www.zacks.com/stock/news/2296578/chevron-cvx-stock-barely-moves-in-a-month-an-opportunity?cid=CS-STOCKNEWSAPI-FT-analyst_blog|most_popular_stocks-2296578')
# ('CMG', '"TEAM CHIPOTLE" RETURNS WITH A NEW LIMITED-TIME MENU FEATURING THE GO-TO ORDERS FOR AMERICA\'S TOP ATHLETES', '2024-07-01 08:08:00', 'prnewswire.com', 'Anthony Edwards, Sophia Smith, Taylor Fritz, Sara Hughes, and Jagger Eaton will have their favorite orders featured on the Chipotle app and Chipotle.com as limited-edition menu items Chipotle has also launched new episodes of its "Unwrapped" series featuring behind-the-scenes content with each athlete Starting July 25, the brand will bring back gold foil burritos in the U.S. and serve gold foil burritos for the first time at its restaurants in France NEWPORT BEACH, Calif. , July 1, 2024 /PRNewswire/ -- Chipotle Mexican Grill (NYSE: CMG) today announced it is celebrating American athletes with digital menu items exclusively on the Chipotle app and Chipotle.com and new episodes of its popular "Unwrapped" video series.', 'https://www.prnewswire.com/news-releases/team-chipotle-returns-with-a-new-limited-time-menu-featuring-the-go-to-orders-for-americas-top-athletes-302186709.html')
# ('C', 'JPMorgan downgraded on valuation, while Bank of America shines as top pick: analyst', '2024-07-08 09:30:00', 'marketwatch.com', 'JPMorgan Chase & Co. on Monday drew a downgrade to peer perform while Bank of America Corp. was highlighted as a top pick at Wolfe Research before the big banks deliver profit updates in the coming days.', 'https://www.marketwatch.com/story/jpmorgan-downgraded-on-valuation-while-bank-of-america-shines-as-top-pick-analyst-88d2efba')
# ('COST', "Gen Z Discovers Costco, Sam's Club and the Joy of Buying Groceries in Bulk", '2024-07-05 08:00:00', 'wsj.com', 'Young adults are battling sticker shock at the grocery store by supersizing their groceries. They are turning to bulk purchases, splitting their food costs with friends, roommates, family and neighbors.', 'https://www.wsj.com/business/retail/inflation-gen-z-grocery-shopping-costco-sams-club-be2bef88')
# ('CRWD', 'CrowdStrike faces major brand damage from global outage but analysts remain bullish on long-term potential', '2024-07-19 09:46:38', 'proactiveinvestors.com', "CrowdStrike Holdings Inc (NASDAQ:CRWD) will need to go into the next gear over the coming weeks and months to curtail the damage to its brand stemming from Friday's outage, Wedbush analysts say. \xa0 An update from the cybersecurity company resulted in a major IT outage, impacting businesses, airports and consumers globally.", 'https://www.proactiveinvestors.com/companies/news/1052287')
# ('CVS', 'CVS Health Corporation Is Under Probe By The Schall Law Firm Regarding Certain Allegations And Investors Are Urged To Participate In The Investigation', '2024-07-08 13:00:00', 'accesswire.com', 'LOS ANGELES, CA / ACCESSWIRE / July 8, 2024 / The Schall Law Firm, a national shareholder rights litigation firm, announces that it is investigating claims on behalf of investors of CVS Health Corporation ("CVS" or "the Company") (NYSE:CVS) for violations of the securities laws. The investigation focuses on whether the Company issued false and/or misleading statements and/or failed to disclose information pertinent to investors.', 'https://www.accesswire.com/viewarticle.aspx?id=886263&lang=en')
# ('DAL', 'Should You Buy Delta Air Lines Stock Ahead of Q2 Earnings?', '2024-07-09 12:30:21', 'zacks.com', 'Investors will get a glimpse at how the travel industry is fairing with Delta Air Lines (DAL) set to report its Q2 results on Thursday, July 11.', 'https://www.zacks.com/stock/news/2298611/should-you-buy-delta-air-lines-stock-ahead-of-q2-earnings?cid=CS-STOCKNEWSAPI-FT-stocks_in_the_news-2298611')
# ('ENPH', 'Enphase Energy, Inc. Sued for Securities Law Violations - Contact The Gross Law Firm Before July 29, 2024 to Discuss Your Rights – ENPH', '2024-07-15 10:46:00', 'globenewswire.com', 'NEW YORK, July 15, 2024 (GLOBE NEWSWIRE) -- The Gross Law Firm issues the following notice to shareholders of Enphase Energy, Inc. (NASDAQ: ENPH).', 'https://www.globenewswire.com/news-release/2024/07/15/2913185/0/en/Enphase-Energy-Inc-Sued-for-Securities-Law-Violations-Contact-The-Gross-Law-Firm-Before-July-29-2024-to-Discuss-Your-Rights-ENPH.html')
# ('GM', 'Chief Future Officer: Kofi Bruce, General Mills', '2024-07-10 21:51:37', 'youtube.com', "Chief Financial Officers now play a critical role in shaping corporate strategy and positioning organizations to meet future challenges. Bloomberg's monthly program, Chief Future Officer, profiles these leaders and explores the impact they're making on their companies and industries.", 'https://www.youtube.com/watch?v=CgJw06_OgsY')
# ('GS', '2 factors that could boost big bank stocks', '2024-07-08 13:11:47', 'youtube.com', 'As major financial institutions like JPMorgan (JPM), Citi (C), and Wells Fargo (WFC) prepare to release their earnings this week, Macrae Sykes, Gabelli Funds portfolio manager, joins Catalysts to share his outlook on the banking sector. Sykes expresses a bullish stance on bank earnings, highlighting two key factors that could potentially boost reports.', 'https://www.youtube.com/watch?v=YkqI0oGL3fc')
# ('HUM', 'HUM SHAREHOLDER ALERT: Bronstein, Gewirtz & Grossman LLC Reminds Humana Inc. Investors to Join the Class Action Lawsuit!', '2024-07-11 15:00:00', 'accesswire.com', 'NEW YORK, NY / ACCESSWIRE / July 11, 2024 / Bronstein, Gewirtz & Grossman, LLC, a nationally recognized law firm, notifies investors that a class action lawsuit has been filed against Humana Inc. ("Humana" or "the Company") (NYSE:HUM) and certain of its officers. Class Definition: This lawsuit seeks to recover damages against Defendants for alleged violations of the federal securities laws on behalf of all persons and entities that purchased or otherwise acquired Humana securities between July 27, 2022 and January 24, 2024, inclusive (the "Class Period").', 'https://www.accesswire.com/viewarticle.aspx?id=871982&lang=en')
# ('INTC', 'Forget Nvidia: These 2 AI Stocks Are Better Bargain Buys Right Now.', '2024-07-09 04:15:00', 'fool.com', 'Nvidia has been the star of the AI boom, soaring 150% in the first half of the year. The stock still makes a great long-term bet, but other players may represent better bargains today.', 'https://www.fool.com/investing/2024/07/09/forget-nvidia-these-2-ai-stocks-are-better-bargain/')
# ('JNJ', 'CARVYKTI® (ciltacabtagene autoleucel) achieved statistically significant and clinically meaningful improvement in overall survival in landmark CARTITUDE-4 study', '2024-07-02 07:30:00', 'prnewswire.com', 'CARVYKTI ® \xa0is the first and only BCMA-targeted CAR-T cell therapy approved by the U.S. FDA for the treatment of patients with multiple myeloma who have had at least one prior line of therapy RARITAN, N.J. , July 2, 2024 /PRNewswire/ --\xa0Johnson & Johnson (NYSE:JNJ) announced today positive results from a prespecified second interim analysis of the Phase 3 CARTITUDE-4 study evaluating CARVYKTI® (ciltacabtagene autoleucel; cilta-cel) compared to standard therapies of pomalidomide, bortezomib and dexamethasone (PVd) or daratumumab, pomalidomide and dexamethasone (DPd) for the treatment of patients with relapsed or lenalidomide-refractory multiple myeloma after one prior line of therapy.', 'https://www.prnewswire.com/news-releases/carvykti-ciltacabtagene-autoleucel-achieved-statistically-significant-and-clinically-meaningful-improvement-in-overall-survival-in-landmark-cartitude-4-study-302187545.html')
# ('JPM', '3 Must-Watch Financial Stocks as Sector Approaches Major Breakout', '2024-07-11 10:47:35', 'marketbeat.com', 'The financial sector, and specifically the sector ETF Financial Select Sector SPDR Fund NYSE: XLF, has been consolidating for several months and is now approaching a significant breakout level.', 'https://www.marketbeat.com/stock-ideas/3-must-watch-financial-stocks-as-sector-approaches-major-breakout/')
# ('LW', 'Investors in Lamb Weston Holdings, Inc. Should Contact Levi & Korsinsky Before August 12, 2024 to Discuss Your Rights - LW', '2024-07-14 10:30:00', 'accesswire.com', 'NEW YORK, NY / ACCESSWIRE / July 14, 2024 / If you suffered a loss on your Lamb Weston Holdings, Inc. (NYSE:LW) investment and want to learn about a potential recovery under the federal securities laws, follow the link below for more information: https://zlk.com/pslra-1/lamb-weston-holdings-lawsuit-submission-form?prid=90663&wire=1 or contact Joseph E. Levi, Esq.', 'https://www.accesswire.com/viewarticle.aspx?id=888589&lang=en')
# ('LLY', "Here's Why Eli Lilly (LLY) is a Strong Momentum Stock", '2024-07-08 13:47:38', 'zacks.com', 'Wondering how to pick strong, market-beating stocks for your investment portfolio? Look no further than the Zacks Style Scores.', 'https://www.zacks.com/stock/news/2297922/here-s-why-eli-lilly-lly-is-a-strong-momentum-stock?cid=CS-STOCKNEWSAPI-FT-tale_of_the_tape|zacks_education_momentum_score-2297922')
# ('META', '9 Popular AI Stocks to Buy With $500 Right Now', '2024-07-14 09:15:26', '247wallst.com', 'Artificial intelligence seems to be everywhere these days. Once upon a time, AI was a thing of science fiction.', 'https://247wallst.com/investing/2024/07/14/popular-ai-stocks-to-buy-with-500-right-now/')
# ('MU', 'Micron: Market Overreacted, Time To Load Up - Maintaining Buy', '2024-07-02 18:27:08', 'seekingalpha.com', "Micron Technology reported FY2024 results and outlook, disappointing investors' high AI expectations after the June rally. We say load up on the pullback. Our positive outlook is based on our expectations of higher DRAM sales due to AI-driven demand for HBM and the arrival of AI PC in 2025. We expect hyper-demand from AI for HBM to put DRAM into shortage for the next 1-2 years, at least.", 'https://seekingalpha.com/article/4702138-micron-market-overreacted-time-to-load-up-maintaining-buy')
# ('MSFT', '3 Growth Beasts (Not Named Nvidia) That Have Been 10-Baggers Over the Past 10 Years', '2024-07-18 04:55:00', 'fool.com', "Microsoft's evolving business means there are plenty of opportunities for the company to grow even bigger. Palo Alto Networks is a big name in cybersecurity, and its revenue has doubled in just three years.", 'https://www.fool.com/investing/2024/07/18/growth-stocks-not-nvidia-10-bagger-10-years/')
# ('MS', 'This is how much the largest 20 U.S. banks raised dividends after stress tests', '2024-07-01 08:44:00', 'marketwatch.com', 'With another round of Federal Reserve stress tests in the books, many large U.S. banks have already announced dividend increases. Analysts at Jefferies compiled the data in a report sent to clients early Monday.', 'https://www.marketwatch.com/story/this-is-how-much-the-largest-20-u-s-banks-raised-dividends-after-stress-tests-be2f3501')
# ('NDAQ', 'Nasdaq Gains 1%; LegalZoom Shares Slide', '2024-07-10 14:31:27', 'benzinga.com', 'U.S. stocks traded higher toward the end of trading, with the Nasdaq Composite gaining around 1% on Wednesday.', 'https://www.benzinga.com/news/earnings/24/07/39716266/nasdaq-gains-1-legalzoom-shares-slide')
# ('NFLX', "Netflix Q2 Earnings Highlights: Revenue Beat, EPS Beat, Advertising Revenue 'More Meaningful,' 'Squid Game' Multiplayer Game Coming", '2024-07-18 16:27:04', 'benzinga.com', 'Streaming giant Netflix Inc NFLX reported second-quarter financial results after the market close Thursday.', 'https://www.benzinga.com/news/earnings/24/07/39849026/netflix-q2-earnings-highlights-revenue-beat-eps-beat-advertising-revenue-more-meaningful-squid-game')
# ('NKE', 'Class Action Filed Against NIKE, Inc. (NKE) Seeking Recovery for Investors - Contact Levi & Korsinsky', '2024-07-14 13:00:00', 'accesswire.com', 'NEW YORK, NY / ACCESSWIRE / July 14, 2024 / If you suffered a loss on your NIKE, Inc. (NYSE:NKE) investment and want to learn about a potential recovery under the federal securities laws, follow the link below for more information: https://zlk.com/pslra-1/nike-lawsuit-submission-form?prid=90676&wire=1 or contact Joseph E. Levi, Esq.', 'https://www.accesswire.com/viewarticle.aspx?id=888605&lang=en')
# ('NVDA', 'Nvidia, ASML and Other Chip Stocks Sink on Worries About Tougher Trade Curbs, Geopolitics', '2024-07-17 12:25:14', 'investopedia.com', 'Nvidia (NVDA), Qualcomm (QCOM), and other chip stocks tumbled Wednesday following reports of potential government moves that could negatively impact the sector.', 'https://www.investopedia.com/nvidia-asml-and-other-chip-stocks-sink-on-worries-about-tougher-trade-curbs-geopolitics-8679217')
# ('PARA', 'Special committee of Paramount Global endorses plan to merge with Skydance Media, source says', '2024-07-07 17:53:52', 'reuters.com', 'Tech scion David Ellison moved one step closer to gaining control of Paramount Global , with a special committee voting Sunday to support a merger with his Skydance Media, a source close to the deal told Reuters.', 'https://www.reuters.com/markets/deals/special-committee-paramount-global-endorses-plan-merge-with-skydance-media-2024-07-07/')
# ('PEP', '7 Diversified Income Powerhouses for Lifelong Cash Flow', '2024-07-08 06:45:00', 'investorplace.com', 'Diversified income stocks are a smart choice for investors seeking lifelong cash flow. They offer a reliable stream of income from multiple sources and provide stability and growth potential in any market condition.', 'https://investorplace.com/2024/07/7-diversified-income-powerhouses-for-lifelong-cash-flow/')
# ('PFE', 'Weighing the Future of Weight Loss Drugs', '2024-07-02 13:44:09', 'youtube.com', 'How are obesity drugs impacting other industries? Julia Angeles discusses the future of weight loss drugs.', 'https://www.youtube.com/watch?v=K7tk0xNaWBA')
# ('O', 'Dividend Harvesting Portfolio Week 174: $17,400 Allocated, $1,552.82 In Projected Dividends', '2024-07-04 09:00:00', 'seekingalpha.com', 'First half of 2024 is profitable for investors, S&P 500 up 14.48% and Dividend Harvesting Portfolio ROI at 14.05%. Market outlook positive with Fed rate cuts expected, unemployment increase may signal recession. Portfolio generates $1,552.82 in forward dividend income, focusing on diversification and income growth.', 'https://seekingalpha.com/article/4701946-dividend-harvesting-portfolio-week-174-17400-allocated-1552-82-in-projected-dividends')
# ('CRM', 'CRM INVESTIGATION NOTIFICATION: BFA Law Notifies Salesforce, Inc. (NYSE:CRM) Investors that it is Investigating Salesforce for Securities Fraud, Contact Us if You Lost Money', '2024-07-01 08:02:00', 'globenewswire.com', 'NEW YORK, July 01, 2024 (GLOBE NEWSWIRE) -- Leading securities law firm Bleichmar Fonti & Auld LLP announces an investigation into Salesforce, Inc. (NYSE:CRM) for potential violations of the federal securities laws. If you invested in Salesforce, you are encouraged to submit your information at https://www.bfalaw.com/cases-investigations/salesforce-inc.', 'https://www.globenewswire.com/news-release/2024/07/01/2906683/0/en/CRM-INVESTIGATION-NOTIFICATION-BFA-Law-Notifies-Salesforce-Inc-NYSE-CRM-Investors-that-it-is-Investigating-Salesforce-for-Securities-Fraud-Contact-Us-if-You-Lost-Money.html')
# ('SMCI', '1 Phenomenal Stock That Could Join Microsoft, Apple, Nvidia, Alphabet, Amazon, and Meta in the $1 Trillion Club', '2024-07-07 05:01:00', 'fool.com', "The advent of generative AI and its rapid deployment has driven Super Micro Computer's recent rally. The company's distinguished track record of providing customized servers for customers of all sizes, as well as demand driven by AI, has lit a fire under the stock.", 'https://www.fool.com/investing/2024/07/07/1-phenomenal-stock-that-could-join-microsoft-apple/')
# ('TGT', 'Target Hospitality Being Investigated on Behalf of Target Hospitality Corp. Investors. Contact Levi & Korsinsky For Details', '2024-07-05 14:15:00', 'accesswire.com', 'NEW YORK, NY / ACCESSWIRE / July 5, 2024 / Levi & Korsinsky notifies investors that it has commenced an investigation of Target Hospitality Corp. ("Target Hospitality") (NASDAQ:TH) concerning possible violations of federal securities laws. Target Hospitality issued a press release on June 10, 2024, announcing that it had "received notice that the U.S. government intends to terminate the existing South Texas Family Residential Center (\'STFRC\') services agreement with Target\'s migrant programming partner (\'STFRC Partner\'), effective in 60 days, or on or about August 9, 2024 (\'Effective Date\').', 'https://www.accesswire.com/viewarticle.aspx?id=885605&lang=en')
# ('TSLA', '3 Stocks Down 42% to 75% to Buy Right Now', '2024-07-16 04:42:00', 'fool.com', "Carnival is successfully converting strong travel demand into higher profitability. Tesla saw a jump in electric vehicle deliveries last quarter, which could signal the end of the stock's recent slump.", 'https://www.fool.com/investing/2024/07/16/3-stocks-down-42-to-75-to-buy-right-now/')
# ('UNH', 'UNITEDHEALTH SHAREHOLDER ALERT BY FORMER LOUISIANA ATTORNEY GENERAL: KAHN SWICK & FOTI, LLC REMINDS INVESTORS WITH LOSSES IN EXCESS OF $100,000 of Lead Plaintiff Deadline in Class Action Lawsuit Against UnitedHealth Group Inc.- UNH', '2024-07-11 20:30:00', 'accesswire.com', 'NEW ORLEANS, LA / ACCESSWIRE / July 11, 2024 / Kahn Swick & Foti, LLC ("KSF") and KSF partner, former Attorney General of Louisiana, Charles C. Foti, Jr., remind investors that they have until July 15, 2024 to file lead plaintiff applications in a securities class action lawsuit against UnitedHealth Group Inc. (NYSE:UNH), if they purchased the Company\'s shares between March 14, 2022, and February 27, 2024, inclusive (the "Class Period").', 'https://www.accesswire.com/viewarticle.aspx?id=888069&lang=en')
# ('V', 'Visa Promotes Aurélien Pichon to Global Head of Client Services', '2024-07-01 18:55:38', 'pymnts.com', 'Visa has promoted Aurélien Pichon, who had been its head of client services in Central Europe, Middle East and Africa (CEMEA) for the last two years, to global head of client services, effective immediately.', 'https://www.pymnts.com/visa/2024/visa-promotes-aurelien-pichon-to-global-head-of-client-services/')
# ('WBA', '3 Things You Need to Know if You Buy Walgreens Boots Alliance Stock Today', '2024-07-14 14:05:00', 'fool.com', 'Walgreens Boots Alliance is planning to scale down its operations. Its major growth campaign looks to be stalled, at least for now.', 'https://www.fool.com/investing/2024/07/14/3-things-you-need-to-know-if-you-buy-walgreens-boo/')
# ('WMT', "Walmart Chile workers' union launches strike after talks fail", '2024-07-10 10:21:38', 'reuters.com', "Walmart Chile's workers union launched a strike on Wednesday, days after negotiations for a new collective bargaining agreement failed, the union said in a statement.", 'https://www.reuters.com/business/retail-consumer/walmart-chile-workers-union-launches-strike-after-talks-fail-2024-07-10/')

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v4/stock-news-sentiments-rss-feed?page=0&apikey=kZ2IufkTebqBJoodhTojSFLZpBqhyKbO")
print(get_jsonparsed_data(url))
# Out:
# <ipython-input-31-3b68382d3442>:2: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# [{'symbol': 'SPHR', 'publishedDate': '2024-07-25T20:18:00.000Z', 'title': "Ken Griffin's Citadel boosts stake in James Dolan's Sphere weeks after Steve Cohen's investment", 'image': 'https://cdn.snapi.dev/images/v1/6/b/entertainment-diversified2-2546667.jpg', 'site': 'nypost.com', 'text': "Citadel's stake in Sphere Entertainment rose from 1.6% to 5.3%, according to SEC filings released on Monday.", 'url': 'https://nypost.com/2024/07/25/business/citadel-boosts-stake-in-james-dolans-sphere-after-steve-cohen-investment/', 'sentiment': 'Positive', 'sentimentScore': 0.35}, {'symbol': 'BNO', 'publishedDate': '2024-07-25T20:17:58.000Z', 'title': 'Crude Oil Price Forecast: Reversal Day Signals Strength', 'image': 'https://cdn.snapi.dev/images/v1/q/g/oil28-2475005-2546665.jpg', 'site': 'fxempire.com', 'text': 'Signs of a bullish reversal in crude oil emerge as it bounces from 77.06, reclaiming key levels and targeting a breakout above 79.45.', 'url': 'https://www.fxempire.com/forecasts/article/crude-oil-price-forecast-reversal-day-signals-strength-1448878', 'sentiment': 'Positive', 'sentimentScore': 0.35}, {'symbol': 'FHI', 'publishedDate': '2024-07-25T20:17:00.000Z', 'title': 'Federated Hermes, Inc. reports record assets under management with second quarter 2024 earnings', 'image': 'https://cdn.snapi.dev/images/v1/g/b/press3-2546650.jpg', 'site': 'prnewswire.com', 'text': "Total assets under management reach a record $782.7 billion Money market assets reach a record $586.6 billion Q2 2024 earnings per diluted share of $0.20, including a ($0.76) per diluted share non-cash intangible asset impairment charge Board declares $0.31 per share dividend PITTSBURGH , July 25, 2024 /PRNewswire/ -- Federated Hermes, Inc. (NYSE: FHI), a global leader in active, responsible investing, today reported earnings per diluted share (EPS) of $0.20 for Q2 2024, compared to\xa0$0.81 for the same quarter last year, on net income of $21.0 million for Q2 2024, compared to\xa0$72.2 million for Q2 2023. Federated Hermes' Q2 2024 results include a $66.3 million non-cash expense, or ($0.76) per diluted share, related to the impairment of an indefinite-lived intangible asset.", 'url': 'https://www.prnewswire.com/news-releases/federated-hermes-inc-reports-record-assets-under-management-with-second-quarter-2024-earnings-302207050.html', 'sentiment': 'Positive', 'sentimentScore': 0.142}, {'symbol': 'KR', 'publishedDate': '2024-07-25T20:16:17.000Z', 'title': 'Albertsons and Kroger agree to pause merger amid legal, regulatory challenges', 'image': 'https://cdn.snapi.dev/images/v1/s/c/stores-grocery3-2546627.jpg', 'site': 'foxbusiness.com', 'text': 'Kroger and Albertsons announced that the two companies agreed to temporarily pause their $25 billion merger as a lawsuit filed by Colorado challenging their merger goes to trial.', 'url': 'https://www.foxbusiness.com/markets/albertsons-kroger-agree-pause-merger-amid-legal-regulatory-challenges', 'sentiment': 'Neutral', 'sentimentScore': -0.1}, {'symbol': 'GM', 'publishedDate': '2024-07-25T20:16:15.000Z', 'title': 'Former Solicitor General Paul Clement joins Coinbase board', 'image': 'https://cdn.snapi.dev/images/v1/q/7/co15-2473400-2546626.jpg', 'site': 'foxbusiness.com', 'text': "Paul Clement previously served as the former solicitor general under the Bush administration and will join the board at Coinbase, the U.S.'s largest cryptocurrency exchange.", 'url': 'https://www.foxbusiness.com/markets/former-solicitor-general-paul-clement-joins-coinbase-board', 'sentiment': 'Positive', 'sentimentScore': 0.2}, {'symbol': 'NCSM', 'publishedDate': '2024-07-25T20:15:00.000Z', 'title': 'NCS Multistage Holdings, Inc. Schedules Second Quarter 2024 Earnings Release and Conference Call', 'image': 'https://cdn.snapi.dev/images/v1/h/e/conf1-2546638.jpg', 'site': 'globenewswire.com', 'text': 'HOUSTON, July 25, 2024 (GLOBE NEWSWIRE) -- NCS Multistage Holdings, Inc. (“NCS” or the “Company”) (NASDAQ:NCSM) will host a conference call to discuss i ...

# %%
import sqlite3
import logging
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from transformers import pipeline
from typing import List, Dict, Tuple
import json
from urllib.request import urlopen
import certifi
import pandas as pd

# Function to connect to the database and fetch news data
def fetch_news_from_db(db_path: str, query: str) -> List[Dict]:
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute(query)
        rows = cursor.fetchall()
        conn.close()
        # Convert rows to a list of dictionaries
        news_data = []
        for row in rows:
            news_data.append({"title": row[0], "text": row[1]})
        return news_data
    except sqlite3.Error as e:
        logger.error(f"Error fetching news data from database: {e}")
        return []

# Function to fetch sentiment data from the API
def get_jsonparsed_data(url: str) -> List[Dict]:
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

db_path = "News.db"
query = "SELECT * FROM stock_news"

news_data = fetch_news_from_db(db_path, query)
api_url = "https://financialmodelingprep.com/api/v4/stock-news-sentiments-rss-feed?page=0&apikey=kZ2IufkTebqBJoodhTojSFLZpBqhyKbO"
api_sentiments = get_jsonparsed_data(api_url)
# Extract symbol and sentiment from the API data
symbol_sentiments = [(item['symbol'], item['sentiment']) for item in api_sentiments]

# Convert to DataFrame
df = pd.DataFrame(symbol_sentiments, columns=['symbol', 'sentiment'])

df
# Out:
# <ipython-input-7-667ddcf334b8>:32: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
#    symbol sentiment
# 0    AMED  Positive
# 1   NHYDY  Positive
# 2    CAKE  Positive
# 3   NABZY  Positive
# 4    PGRE  Positive
# ..    ...       ...
# 95    CVS  Negative
# 96   ENPH  Negative
# 97    ODD  Negative
# 98   RIVN  Negative
# 99    DOW  Positive
#
# [100 rows x 2 columns]

# %%
accuracy_dict = {}

# %%
import sqlite3
import logging
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from transformers import pipeline
from typing import List, Dict, Tuple
import pandas as pd
import json
import certifi
from urllib.request import urlopen
from sklearn.metrics import accuracy_score

# Configure logging to print to the notebook output
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# Download the VADER lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Initialize the sentiment analysis pipelines
pipelines = {
    "FinBERT": pipeline("text-classification", model="ProsusAI/finbert"),
    "DistilBERT": pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english", revision="af0f99b"),
    "FinBERT Tone": pipeline("text-classification", model="yiyanghkust/finbert-tone"),
    "DistilRoberta": pipeline("text-classification", model="mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"),
    "FinTwitBERT": pipeline("text-classification", model="StephanAkkerman/FinTwitBERT-sentiment"),
    "Sentiment Roberta": pipeline("text-classification", model="siebert/sentiment-roberta-large-english")
}

# Function to connect to the database and fetch news data
def fetch_news_from_db(db_path: str, query: str) -> List[Dict]:
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute(query)
        rows = cursor.fetchall()
        conn.close()
        # Convert rows to a list of dictionaries
        news_data = []
        for row in rows:
            news_data.append({"title": row[0], "text": row[1]})
        return news_data
    except sqlite3.Error as e:
        logger.error(f"Error fetching news data from database: {e}")
        return []

# Function to preprocess text data
def preprocess_text(text: str) -> str:
    text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = text.strip()  # Remove leading and trailing whitespace
    return text

# Function to analyze sentiment using multiple models
def analyze_sentiment(text: str) -> List[Tuple[str, Dict]]:
    results = []
    text = preprocess_text(text)

    # VADER
    vader_result = sia.polarity_scores(text)
    if vader_result['compound'] != 0:
        label = 'POSITIVE' if vader_result['compound'] > 0 else 'NEGATIVE'
        results.append(('VADER', {'label': label, 'score': abs(vader_result['compound'])}))

    # Other models
    for model_name, sentiment_pipeline in pipelines.items():
        result = sentiment_pipeline(text)
        if result:
            label = result[0]['label']
            score = result[0]['score']
            # Normalize label and score interpretation
            if label.lower() in ['positive', 'negative', 'neutral', 'bullish', 'bearish']:
                normalized_label = label.upper()
                if normalized_label in ['POSITIVE', 'BULLISH']:
                    normalized_score = score
                elif normalized_label in ['NEGATIVE', 'BEARISH']:
                    normalized_score = -score
                else:
                    normalized_score = 0  # Neutral scores should contribute 0
                results.append((model_name, {'label': normalized_label, 'score': normalized_score}))

    return results

# Function to calculate the ensemble sentiment score
def ensemble_sentiment(sentiments: List[Tuple[str, Dict]]) -> Tuple[float, str]:
    weights = {
        'FinBERT': 4,
        'FinBERT Tone': 3,
        'Sentiment Roberta': 3,
        'DistilRoberta': 2,
        'FinTwitBERT': 2,
        'DistilBERT': 1,
        'VADER': 1
    }
    score = 0
    total_weight = 0
    for model, sentiment in sentiments:
        weight = weights.get(model, 1)
        total_weight += weight
        score += weight * sentiment['score']
    if total_weight == 0:
        return 0.0, "NEUTRAL"
    final_score = score / total_weight
    final_label = 'POSITIVE' if final_score > 0 else 'NEGATIVE'
    return final_score, final_label, weights

# Function to build a dictionary of symbols and their ensemble sentiment scores
def build_symbol_sentiment_dict(news_data: List[Dict]) -> Dict[str, float]:
    symbol_sentiment_dict = {}
    for article in news_data:
        headline = article.get("title", "")
        snippet = article.get("text", "")

        # Extract symbol from headline (assuming the symbol is mentioned in the headline)
        match = re.search(r'\b[A-Z]{1,5}\b', headline)
        if match:
            symbol = match.group(0)
            combined_text = f"{headline} {snippet}"
            combined_sentiments = analyze_sentiment(combined_text)
            combined_ensemble_score, _, weights = ensemble_sentiment(combined_sentiments)
            symbol_sentiment_dict[symbol] = combined_ensemble_score

    return symbol_sentiment_dict, weights

# Function to fetch sentiment data from the API
def get_jsonparsed_data(url: str) -> List[Dict]:
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# Fetch news data
db_path = "News.db"
query = "SELECT * FROM stock_news"
news_data = fetch_news_from_db(db_path, query)

# Build the symbol sentiment dictionary
symbol_sentiment_dict, weights = build_symbol_sentiment_dict(news_data)

# Fetch API sentiments
api_url = "https://financialmodelingprep.com/api/v4/stock-news-sentiments-rss-feed?page=0&apikey=kZ2IufkTebqBJoodhTojSFLZpBqhyKbO"
api_sentiments = get_jsonparsed_data(api_url)

# Extract symbol and sentiment from the API data
symbol_sentiments = [(item['symbol'], item['sentiment']) for item in api_sentiments]

# Convert API data to DataFrame
df = pd.DataFrame(symbol_sentiments, columns=['symbol', 'sentiment'])

# Convert the symbol sentiment dictionary to a DataFrame
symbol_sentiment_df = pd.DataFrame(list(symbol_sentiment_dict.items()), columns=['symbol', 'ensemble_sentiment'])

# Merge the two DataFrames on the 'symbol' column
comparison_df = pd.merge(df, symbol_sentiment_df, on='symbol', how='outer')

# Assign labels to the ensemble sentiment scores
comparison_df['ensemble_label'] = comparison_df['ensemble_sentiment'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))
comparison_df = comparison_df.dropna()
accuracy = accuracy_score(comparison_df['sentiment'], comparison_df['ensemble_label'])

accuracy_dict[weights.values()] = accuracy

accuracy
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# <ipython-input-49-90b9f0185522>:136: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# 0.23076923076923078

# %%
accuracy_dict
# Out:
# {dict_values([4, 3, 3, 2, 2, 1, 1]): 0.4444444444444444,
#  dict_values([3, 3, 3, 2, 2, 1, 1]): 0.4444444444444444,
#  dict_values([5, 4, 3, 3, 2, 2, 1]): 0.3076923076923077,
#  dict_values([4, 4, 3, 3, 2, 2, 1]): 0.3076923076923077,
#  dict_values([4, 4, 4, 3, 2, 2, 1]): 0.23076923076923078,
#  dict_values([4, 3, 3, 2, 2, 2, 1]): 0.3076923076923077,
#  dict_values([6, 5, 4, 3, 1, 2, 2]): 0.23076923076923078,
#  dict_values([4, 4, 3, 2, 2, 1, 1]): 0.23076923076923078,
#  dict_values([4, 3, 3, 2, 2, 2, 1]): 0.3076923076923077,
#  dict_values([4, 3, 4, 2, 2, 1, 1]): 0.23076923076923078,
#  dict_values([4, 2, 3, 2, 2, 1, 1]): 0.23076923076923078,
#  dict_values([4, 3, 3, 2, 2, 3, 1]): 0.23076923076923078,
#  dict_values([4, 3, 3, 2, 3, 1, 1]): 0.3076923076923077,
#  dict_values([3.5, 3, 3, 2, 2, 1, 1]): 0.23076923076923078,
#  dict_values([4, 3, 3, 2, 2, 1, 3]): 0.23076923076923078}

# %%
import sqlite3
import logging
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from transformers import pipeline
from typing import List, Dict, Tuple

# Configure logging to print to the notebook output
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# Download the VADER lexicon
nltk.download('vader_lexicon')

# Initialize the VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Initialize the sentiment analysis pipelines
pipelines = {
    "FinBERT": pipeline("text-classification", model="ProsusAI/finbert"),
    "DistilBERT": pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english", revision="af0f99b"),
    "FinBERT Tone": pipeline("text-classification", model="yiyanghkust/finbert-tone"),
    "DistilRoberta": pipeline("text-classification", model="mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"),
    "FinTwitBERT": pipeline("text-classification", model="StephanAkkerman/FinTwitBERT-sentiment"),
    "Sentiment Roberta": pipeline("text-classification", model="siebert/sentiment-roberta-large-english")
}

# Function to connect to the database and fetch news data
def fetch_news_from_db(db_path: str, query: str) -> List[Dict]:
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute(query)
        rows = cursor.fetchall()
        conn.close()
        # Convert rows to a list of dictionaries
        news_data = []
        for row in rows:
            news_data.append({"title": row[0], "text": row[1]})
        return news_data
    except sqlite3.Error as e:
        logger.error(f"Error fetching news data from database: {e}")
        return []

# Function to preprocess text data
def preprocess_text(text: str) -> str:
    text = re.sub(r'<.*?>', '', text)  # Remove HTML tags
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = text.strip()  # Remove leading and trailing whitespace
    return text

# Function to analyze sentiment using multiple models
def analyze_sentiment(text: str) -> List[Tuple[str, Dict]]:
    results = []
    text = preprocess_text(text)

    # VADER
    vader_result = sia.polarity_scores(text)
    if vader_result['compound'] != 0:
        label = 'POSITIVE' if vader_result['compound'] > 0 else 'NEGATIVE'
        results.append(('VADER', {'label': label, 'score': abs(vader_result['compound'])}))

    # Other models
    for model_name, sentiment_pipeline in pipelines.items():
        result = sentiment_pipeline(text)
        if result:
            label = result[0]['label']
            score = result[0]['score']
            # Normalize label and score interpretation
            if label.lower() in ['positive', 'negative', 'neutral', 'bullish', 'bearish']:
                normalized_label = label.upper()
                if normalized_label in ['POSITIVE', 'BULLISH']:
                    normalized_score = score
                elif normalized_label in ['NEGATIVE', 'BEARISH']:
                    normalized_score = -score
                else:
                    normalized_score = 0  # Neutral scores should contribute 0
                results.append((model_name, {'label': normalized_label, 'score': normalized_score}))

    return results

# Function to calculate the ensemble sentiment score
def ensemble_sentiment(sentiments: List[Tuple[str, Dict]]) -> Tuple[float, str]:
    weights = {
        'FinBERT': 4,
        'FinBERT Tone': 3,
        'Sentiment Roberta': 3,
        'DistilRoberta': 2,
        'FinTwitBERT': 1,
        'DistilBERT': 1,
        'VADER': 1
    }
    score = 0
    total_weight = 0
    for model, sentiment in sentiments:
        weight = weights.get(model, 1)
        total_weight += weight
        score += weight * sentiment['score']
    if total_weight == 0:
        return 0.0, "NEUTRAL"
    final_score = score / total_weight
    final_label = 'POSITIVE' if final_score > 0 else 'NEGATIVE'
    return final_score, final_label

# Function to process and display news articles
def process_news_articles(news_data: List[Dict]) -> None:
    if not news_data:
        logger.info("No news data to process.")
        return

    for article in news_data:
        headline = article.get("title", "")
        snippet = article.get("text", "")

        # Combine headline and snippet
        combined_text = f"{headline} {snippet}"

        # Analyze sentiment of the combined text
        combined_sentiments = analyze_sentiment(combined_text)

        # Calculate ensemble sentiment
        combined_ensemble_score, combined_ensemble_label = ensemble_sentiment(combined_sentiments)

        # Print the results
        print(f"\n{'-'*80}")
        print(f"Headline: {headline}")
        print(f"Snippet: {snippet}")
        print(f"Combined Ensemble Sentiment Score: {combined_ensemble_score:.2f} ({combined_ensemble_label})")
        print("Combined Sentiments:")
        for model, sentiment in combined_sentiments:
            print(f"  - {model}: {sentiment['label']} (score: {sentiment['score']:.2f})")
        print(f"{'-'*80}\n")

# Main function
def main():
    db_path = "News.db"
    query = "SELECT * FROM stock_news"

    news_data = fetch_news_from_db(db_path, query)
    if news_data:
        process_news_articles(news_data)
    else:
        logger.error("Failed to fetch news data.")

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# --------------------------------------------------------------------------------
# Headline: AMD
# Snippet: AMD Inventory Headwinds & Robust MRVL Demand
# Combined Ensemble Sentiment Score: 0.35 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.23)
#   - FinBERT: NEGATIVE (score: -0.73)
#   - DistilBERT: POSITIVE (score: 0.98)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.90)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: GOOGL
# Snippet: Google's Kurian approached Wiz, $23B deal could take a week to close, source says
# Combined Ensemble Sentiment Score: -0.25 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.56)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: GOOG
# Snippet: Alphabet (GOOGL) Exceeds Market Returns: Some Facts to Consider
# Combined Ensemble Sentiment Score: 0.36 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.97)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: AMZN
# Snippet: Could This Be Amazon's Next $100 Billion Business?
# Combined Ensemble Sentiment Score: 0.14 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: AAL
# Snippet: American Airlines releases 2023 Sustainability Report
# Combined Ensemble Sentiment Score: 0.28 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.97)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: AAPL
# Snippet: Apple gains after Morgan Stanley calls stock 'top pick' for AI efforts
# Combined Ensemble Sentiment Score: 0.80 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.49)
#   - FinBERT: POSITIVE (score: 0.78)
#   - DistilBERT: NEGATIVE (score: -0.52)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.94)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: T
# Snippet: Can Retirees Still Trust AT&T's 5.8% Dividend Yield?
# Combined Ensemble Sentiment Score: 0.13 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.51)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.52)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: BAC
# Snippet: Bank of America: Let Your Winners Run
# Combined Ensemble Sentiment Score: -0.11 (NEGATIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.48)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.51)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.68)
#   - Sentiment Roberta: NEGATIVE (score: -0.79)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: BIIB
# Snippet: IMMINENT BIIB DEADLINE: Bronstein, Gewirtz & Grossman LLC Reminds Biogen Inc. Investors to Join the Class Action Lawsuit
# Combined Ensemble Sentiment Score: 0.08 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.08)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.87)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: BLK
# Snippet: BlackRock announces $3.22 billion acquisition of Preqin
# Combined Ensemble Sentiment Score: 0.27 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.81)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: BA
# Snippet: Boeing Delivers Most Planes Since Alaska Airlines Blowout—But Still Trails Competitor Airbus
# Combined Ensemble Sentiment Score: 0.70 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: POSITIVE (score: 0.80)
#   - DistilBERT: POSITIVE (score: 0.98)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: POSITIVE (score: 0.99)
#   - FinTwitBERT: BULLISH (score: 0.65)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: AVGO
# Snippet: Broadcom Stock Gets Price-Target Hike For AI Strength
# Combined Ensemble Sentiment Score: 0.74 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.49)
#   - FinBERT: POSITIVE (score: 0.69)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.88)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CVX
# Snippet: Chevron (CVX) Stock Barely Moves in a Month: An Opportunity?
# Combined Ensemble Sentiment Score: -0.36 (NEGATIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.42)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEGATIVE (score: -0.96)
#   - DistilRoberta: POSITIVE (score: 0.99)
#   - FinTwitBERT: BEARISH (score: -0.99)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CMG
# Snippet: "TEAM CHIPOTLE" RETURNS WITH A NEW LIMITED-TIME MENU FEATURING THE GO-TO ORDERS FOR AMERICA'S TOP ATHLETES
# Combined Ensemble Sentiment Score: 0.21 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.20)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.63)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.53)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: C
# Snippet: JPMorgan downgraded on valuation, while Bank of America shines as top pick: analyst
# Combined Ensemble Sentiment Score: 0.01 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.20)
#   - FinBERT: NEGATIVE (score: -0.44)
#   - DistilBERT: POSITIVE (score: 0.99)
#   - FinBERT Tone: NEGATIVE (score: -1.00)
#   - DistilRoberta: POSITIVE (score: 0.84)
#   - FinTwitBERT: BEARISH (score: -0.99)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: COST
# Snippet: Gen Z Discovers Costco, Sam's Club and the Joy of Buying Groceries in Bulk
# Combined Ensemble Sentiment Score: 0.31 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.59)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CRWD
# Snippet: CrowdStrike faces major brand damage from global outage but analysts remain bullish on long-term potential
# Combined Ensemble Sentiment Score: -0.35 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.27)
#   - FinBERT: NEGATIVE (score: -0.92)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: NEGATIVE (score: -0.64)
#   - FinTwitBERT: BULLISH (score: 0.39)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CVS
# Snippet: CVS Health Corporation Is Under Probe By The Schall Law Firm Regarding Certain Allegations And Investors Are Urged To Participate In The Investigation
# Combined Ensemble Sentiment Score: 0.09 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.27)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.96)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.99)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: DAL
# Snippet: Should You Buy Delta Air Lines Stock Ahead of Q2 Earnings?
# Combined Ensemble Sentiment Score: 0.14 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: ENPH
# Snippet: Enphase Energy, Inc. Sued for Securities Law Violations - Contact The Gross Law Firm Before July 29, 2024 to Discuss Your Rights – ENPH
# Combined Ensemble Sentiment Score: -0.48 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.49)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEGATIVE (score: -0.95)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.87)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: GM
# Snippet: Chief Future Officer: Kofi Bruce, General Mills
# Combined Ensemble Sentiment Score: 0.28 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: GS
# Snippet: 2 factors that could boost big bank stocks
# Combined Ensemble Sentiment Score: 0.82 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.40)
#   - FinBERT: POSITIVE (score: 0.72)
#   - DistilBERT: POSITIVE (score: 0.98)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: HUM
# Snippet: HUM SHAREHOLDER ALERT: Bronstein, Gewirtz & Grossman LLC Reminds Humana Inc. Investors to Join the Class Action Lawsuit!
# Combined Ensemble Sentiment Score: 0.11 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.55)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.85)
#   - Sentiment Roberta: POSITIVE (score: 0.97)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: INTC
# Snippet: Forget Nvidia: These 2 AI Stocks Are Better Bargain Buys Right Now.
# Combined Ensemble Sentiment Score: 0.54 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.42)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 0.99)
#   - FinTwitBERT: BULLISH (score: 0.71)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: JNJ
# Snippet: CARVYKTI® (ciltacabtagene autoleucel) achieved statistically significant and clinically meaningful improvement in overall survival in landmark CARTITUDE-4 study
# Combined Ensemble Sentiment Score: 0.96 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.75)
#   - FinBERT: POSITIVE (score: 0.95)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.84)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: JPM
# Snippet: 3 Must-Watch Financial Stocks as Sector Approaches Major Breakout
# Combined Ensemble Sentiment Score: 0.35 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.95)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: LW
# Snippet: Investors in Lamb Weston Holdings, Inc. Should Contact Levi & Korsinsky Before August 12, 2024 to Discuss Your Rights - LW
# Combined Ensemble Sentiment Score: -0.25 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.52)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: LLY
# Snippet: Here's Why Eli Lilly (LLY) is a Strong Momentum Stock
# Combined Ensemble Sentiment Score: 0.70 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.51)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.99)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.95)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: META
# Snippet: 9 Popular AI Stocks to Buy With $500 Right Now
# Combined Ensemble Sentiment Score: 0.32 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.42)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.70)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.65)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: MU
# Snippet: Micron: Market Overreacted, Time To Load Up - Maintaining Buy
# Combined Ensemble Sentiment Score: 0.19 (POSITIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.40)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: POSITIVE (score: 0.99)
#   - DistilRoberta: NEGATIVE (score: -0.98)
#   - FinTwitBERT: BEARISH (score: -0.56)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: MSFT
# Snippet: 3 Growth Beasts (Not Named Nvidia) That Have Been 10-Baggers Over the Past 10 Years
# Combined Ensemble Sentiment Score: -0.18 (NEGATIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.38)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.96)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: MS
# Snippet: This is how much the largest 20 U.S. banks raised dividends after stress tests
# Combined Ensemble Sentiment Score: 0.24 (POSITIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.42)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BEARISH (score: -0.81)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: NDAQ
# Snippet: Nasdaq Gains 1%; LegalZoom Shares Slide
# Combined Ensemble Sentiment Score: 0.55 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.56)
#   - FinBERT: POSITIVE (score: 0.91)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.87)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: NFLX
# Snippet: Netflix Q2 Earnings Highlights: Revenue Beat, EPS Beat, Advertising Revenue 'More Meaningful,' 'Squid Game' Multiplayer Game Coming
# Combined Ensemble Sentiment Score: 0.67 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.72)
#   - FinBERT Tone: POSITIVE (score: 1.00)
#   - DistilRoberta: POSITIVE (score: 1.00)
#   - FinTwitBERT: BULLISH (score: 0.70)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: NKE
# Snippet: Class Action Filed Against NIKE, Inc. (NKE) Seeking Recovery for Investors - Contact Levi & Korsinsky
# Combined Ensemble Sentiment Score: -0.57 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEGATIVE (score: -0.76)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.99)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: NVDA
# Snippet: Nvidia, ASML and Other Chip Stocks Sink on Worries About Tougher Trade Curbs, Geopolitics
# Combined Ensemble Sentiment Score: -0.89 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.27)
#   - FinBERT: NEGATIVE (score: -0.92)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEGATIVE (score: -1.00)
#   - DistilRoberta: NEGATIVE (score: -1.00)
#   - FinTwitBERT: BEARISH (score: -1.00)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: PARA
# Snippet: Special committee of Paramount Global endorses plan to merge with Skydance Media, source says
# Combined Ensemble Sentiment Score: 0.18 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.62)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.94)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: PEP
# Snippet: 7 Diversified Income Powerhouses for Lifelong Cash Flow
# Combined Ensemble Sentiment Score: 0.34 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.72)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: PFE
# Snippet: Weighing the Future of Weight Loss Drugs
# Combined Ensemble Sentiment Score: 0.11 (POSITIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.32)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.60)
#   - Sentiment Roberta: POSITIVE (score: 0.98)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: O
# Snippet: Dividend Harvesting Portfolio Week 174: $17,400 Allocated, $1,552.82 In Projected Dividends
# Combined Ensemble Sentiment Score: 0.14 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: CRM
# Snippet: CRM INVESTIGATION NOTIFICATION: BFA Law Notifies Salesforce, Inc. (NYSE:CRM) Investors that it is Investigating Salesforce for Securities Fraud, Contact Us if You Lost Money
# Combined Ensemble Sentiment Score: -0.42 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.60)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -0.99)
#   - FinBERT Tone: NEGATIVE (score: -0.62)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -1.00)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: SMCI
# Snippet: 1 Phenomenal Stock That Could Join Microsoft, Apple, Nvidia, Alphabet, Amazon, and Meta in the $1 Trillion Club
# Combined Ensemble Sentiment Score: 0.52 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.44)
#   - FinBERT: POSITIVE (score: 0.61)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BULLISH (score: 0.96)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: TGT
# Snippet: Target Hospitality Being Investigated on Behalf of Target Hospitality Corp. Investors. Contact Levi & Korsinsky For Details
# Combined Ensemble Sentiment Score: -0.23 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 0.62)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -0.87)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: TSLA
# Snippet: 3 Stocks Down 42% to 75% to Buy Right Now
# Combined Ensemble Sentiment Score: -0.97 (NEGATIVE)
# Combined Sentiments:
#   - FinBERT: NEGATIVE (score: -0.96)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEGATIVE (score: -0.99)
#   - DistilRoberta: NEGATIVE (score: -1.00)
#   - FinTwitBERT: BEARISH (score: -0.78)
#   - Sentiment Roberta: NEGATIVE (score: -0.99)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: UNH
# Snippet: UNITEDHEALTH SHAREHOLDER ALERT BY FORMER LOUISIANA ATTORNEY GENERAL: KAHN SWICK & FOTI, LLC REMINDS INVESTORS WITH LOSSES IN EXCESS OF $100,000 of Lead Plaintiff Deadline in Class Action Lawsuit Against UnitedHealth Group Inc.- UNH
# Combined Ensemble Sentiment Score: -0.55 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.34)
#   - FinBERT: NEGATIVE (score: -0.92)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: BEARISH (score: -1.00)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: V
# Snippet: Visa Promotes Aurélien Pichon to Global Head of Client Services
# Combined Ensemble Sentiment Score: 0.29 (POSITIVE)
# Combined Sentiments:
#   - VADER: POSITIVE (score: 0.34)
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: POSITIVE (score: 1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: WBA
# Snippet: 3 Things You Need to Know if You Buy Walgreens Boots Alliance Stock Today
# Combined Ensemble Sentiment Score: 0.14 (POSITIVE)
# Combined Sentiments:
#   - FinBERT: NEUTRAL (score: 0.00)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEUTRAL (score: 0.00)
#   - FinTwitBERT: NEUTRAL (score: 0.00)
#   - Sentiment Roberta: POSITIVE (score: 1.00)
# --------------------------------------------------------------------------------
#
#
# --------------------------------------------------------------------------------
# Headline: WMT
# Snippet: Walmart Chile workers' union launches strike after talks fail
# Combined Ensemble Sentiment Score: -0.65 (NEGATIVE)
# Combined Sentiments:
#   - VADER: NEGATIVE (score: 0.61)
#   - FinBERT: NEGATIVE (score: -0.94)
#   - DistilBERT: NEGATIVE (score: -1.00)
#   - FinBERT Tone: NEUTRAL (score: 0.00)
#   - DistilRoberta: NEGATIVE (score: -0.92)
#   - FinTwitBERT: BEARISH (score: -0.80)
#   - Sentiment Roberta: NEGATIVE (score: -1.00)
# --------------------------------------------------------------------------------
